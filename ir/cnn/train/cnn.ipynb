# %%
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.layers import Input, Dense, Conv2D, BatchNormalization, Flatten, MaxPooling2D, Lambda, ReLU
import pandas as pd
import numpy as np
import cv2, joblib
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("data.csv")
df.labels = df.labels.astype('category')
# lb = joblib.load("labelbinarizer.joblib")
lb = LabelBinarizer()
lb.fit_transform([
    'circle',
    'up',
    'down',
    'left',
    'right',

    'eight',
    'nine',
    'seven',
    'six',
    'zero',

    'v',
    'w',
    'x',
    'y',
    'z'


])
print(df.isnull().values.any())

b_size = 64
channels = 1
dim = 64

x_train, x_test, y_train, y_test = train_test_split(df.img_path, df.labels,
                                                    stratify=df.labels, test_size=0.1, random_state=2020)
y_train = lb.transform(y_train)
y_test = lb.transform(y_test)
# Out:
# False

# %%
x_train_img = np.empty(shape=(0,dim,dim,channels))
for row in x_train:
    frame = cv2.imread(row, 0)/255
    frame = cv2.resize(frame, (64,64))
    arr = np.reshape(frame, newshape=(1,dim,dim,channels))
    x_train_img = np.append(x_train_img, arr, axis=0)

x_test_img = np.empty(shape=(0,dim,dim,channels))
for row in x_test:
    frame = cv2.imread(row, 0)/255
    frame = cv2.resize(frame, (64,64))
    arr = np.reshape(frame, newshape=(1,dim,dim,channels))
    x_test_img = np.append(x_test_img, arr, axis=0)

print("Images Loaded")
# Out:
# Images Loaded

# %%
input_layer = Input(shape=(dim,dim,channels))
x = Conv2D(32, (3,3), padding="same")(input_layer)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv2D(32, (3,3), padding="same")(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = MaxPooling2D()(x)

x = Conv2D(64, (5,5), padding="same")(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv2D(64, (5,5), padding="same")(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (5,5), padding="same")(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv2D(128, (5,5), padding="same")(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = MaxPooling2D()(x)

x = Conv2D(256, (5,5), padding="same")(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv2D(256, (5,5), padding="same")(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = MaxPooling2D()(x)

x = Flatten()(x)
x = Dense(512, activation='relu')(x)
output = Dense(15, activation='softmax')(x)

# Connect the inputs with the outputs
cnn = Model(inputs=input_layer, outputs=output)

# %%
cnn.compile(loss="categorical_crossentropy",optimizer=Adam(lr=0.00006, decay=1e-6), metrics=['acc'])
cnn.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 64, 64, 32)        320
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64, 64, 32)        128
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 64, 64, 32)        9248
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64, 64, 32)        128
# _________________________________________________________________
# re_lu_18 (ReLU)              (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# re_lu_19 (ReLU)              (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 32, 64)        102464
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# re_lu_20 (ReLU)              (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 16, 128)       204928
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# re_lu_21 (ReLU)              (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 16, 128)       409728
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# re_lu_22 (ReLU)              (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 8, 8, 256)         819456
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# re_lu_23 (ReLU)              (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 8, 8, 256)         1638656
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# re_lu_24 (ReLU)              (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# dense_6 (Dense)              (None, 15)                7695
# =================================================================
# Total params: 5,345,263
# Trainable params: 5,343,343
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
history = cnn.fit(x_train_img, y_train, batch_size=b_size, epochs=100, verbose=1,
                          validation_data=(x_test_img,y_test))
# Out:
# Train on 2268 samples, validate on 252 samples
# Epoch 1/100
# 2268/2268 [==============================] - 48s 21ms/step - loss: 0.5636 - acc: 0.8646 - val_loss: 2.7479 - val_acc: 0.0635
# Epoch 2/100
# 2268/2268 [==============================] - 59s 26ms/step - loss: 0.0175 - acc: 0.9978 - val_loss: 2.9132 - val_acc: 0.0675
# Epoch 3/100
# 2268/2268 [==============================] - 52s 23ms/step - loss: 0.0053 - acc: 0.9996 - val_loss: 3.2279 - val_acc: 0.0675
# Epoch 4/100
# 2268/2268 [==============================] - 48s 21ms/step - loss: 0.0035 - acc: 0.9996 - val_loss: 3.7416 - val_acc: 0.0675
# Epoch 5/100
# 2268/2268 [==============================] - 48s 21ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 4.2406 - val_acc: 0.0675
# Epoch 6/100
# 2268/2268 [==============================] - 48s 21ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 4.7681 - val_acc: 0.0675
# Epoch 7/100
# 2268/2268 [==============================] - 48s 21ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 4.9443 - val_acc: 0.0794
# Epoch 8/100
# 2268/2268 [==============================] - 48s 21ms/step - loss: 8.4455e-04 - acc: 1.0000 - val_loss: 4.7082 - val_acc: 0.0794
# Epoch 9/100
# 2268/2268 [==============================] - 48s 21ms/step - loss: 7.0351e-04 - acc: 1.0000 - val_loss: 4.2161 - val_acc: 0.0794
# Epoch 10/100
# 2268/2268 [==============================] - 47s 21ms/step - loss: 6.5828e-04 - acc: 1.0000 - val_loss: 3.2075 - val_acc: 0.1349
# Epoch 11/100
# 2268/2268 [==============================] - 47s 21ms/step - loss: 5.3288e-04 - acc: 1.0000 - val_loss: 2.2594 - val_acc: 0.3532
# Epoch 12/100
# 2268/2268 [==============================] - 48s 21ms/step - loss: 4.5103e-04 - acc: 1.0000 - val_loss: 1.4270 - val_acc: 0.5635
# Epoch 13/100
# 2268/2268 [==============================] - 47s 21ms/step - loss: 4.5575e-04 - acc: 1.0000 - val_loss: 0.8213 - val_acc: 0.7183
# Epoch 14/100
# 2268/2268 [==============================] - 47s 21ms/step - loss: 4.5228e-04 - acc: 1.0000 - val_loss: 0.4332 - val_acc: 0.8492
# Epoch 15/100
# 2268/2268 [==============================] - 47s 21ms/step - loss: 3.0834e-04 - acc: 1.0000 - val_loss: 0.1934 - val_acc: 0.9405
# Epoch 16/100
# 2268/2268 [==============================] - 47s 21ms/step - loss: 2.5132e-04 - acc: 1.0000 - val_loss: 0.0887 - val_acc: 0.9762
# Epoch 17/100
# 2268/2268 [==============================] - 46s 20ms/step - loss: 2.2598e-04 - acc: 1.0000 - val_loss: 0.0493 - val_acc: 0.9881
# Epoch 18/100
# 2268/2268 [==============================] - 46s 20ms/step - loss: 2.1782e-04 - acc: 1.0000 - val_loss: 0.0323 - val_acc: 0.9881
# Epoch 19/100
# 2268/2268 [==============================] - 47s 21ms/step - loss: 2.0660e-04 - acc: 1.0000 - val_loss: 0.0233 - val_acc: 0.9921
# Epoch 20/100
# 2268/2268 [==============================] - 46s 20ms/step - loss: 1.6266e-04 - acc: 1.0000 - val_loss: 0.0184 - val_acc: 0.9960
# Epoch 21/100
# 2268/2268 [==============================] - 47s 21ms/step - loss: 1.6551e-04 - acc: 1.0000 - val_loss: 0.0172 - val_acc: 0.9960
# Epoch 22/100
# 2268/2268 [==============================] - 48s 21ms/step - loss: 1.5197e-04 - acc: 1.0000 - val_loss: 0.0168 - val_acc: 0.9960
# Epoch 23/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 1.4557e-04 - acc: 1.0000 - val_loss: 0.0157 - val_acc: 0.9960
# Epoch 24/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 2.7939e-04 - acc: 1.0000 - val_loss: 0.0180 - val_acc: 0.9960
# Epoch 25/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 2.3623e-04 - acc: 1.0000 - val_loss: 0.0143 - val_acc: 0.9960
# Epoch 26/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 1.2649e-04 - acc: 1.0000 - val_loss: 0.0141 - val_acc: 0.9960
# Epoch 27/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 1.1541e-04 - acc: 1.0000 - val_loss: 0.0127 - val_acc: 0.9960
# Epoch 28/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 9.7606e-05 - acc: 1.0000 - val_loss: 0.0125 - val_acc: 0.9960
# Epoch 29/100
# 2268/2268 [==============================] - 46s 20ms/step - loss: 9.5612e-05 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9960
# Epoch 30/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 1.1747e-04 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9960
# Epoch 31/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 9.2613e-05 - acc: 1.0000 - val_loss: 0.0147 - val_acc: 0.9960
# Epoch 32/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 8.3678e-05 - acc: 1.0000 - val_loss: 0.0137 - val_acc: 0.9960
# Epoch 33/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 6.5998e-05 - acc: 1.0000 - val_loss: 0.0136 - val_acc: 0.9960
# Epoch 34/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 6.3822e-05 - acc: 1.0000 - val_loss: 0.0137 - val_acc: 0.9960
# Epoch 35/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 6.3162e-05 - acc: 1.0000 - val_loss: 0.0135 - val_acc: 0.9960
# Epoch 36/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 5.9951e-05 - acc: 1.0000 - val_loss: 0.0135 - val_acc: 0.9960
# Epoch 37/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 5.5116e-05 - acc: 1.0000 - val_loss: 0.0135 - val_acc: 0.9960
# Epoch 38/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 4.8525e-05 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 0.9960
# Epoch 39/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 5.3781e-05 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 0.9960
# Epoch 40/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 5.0451e-05 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 0.9960
# Epoch 41/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 4.3634e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 42/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 4.4945e-05 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9960
# Epoch 43/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 3.8674e-05 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9960
# Epoch 44/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 3.8250e-05 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9960
# Epoch 45/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 4.3201e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 46/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 3.3999e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 47/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 3.3557e-05 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9960
# Epoch 48/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 4.9486e-05 - acc: 1.0000 - val_loss: 0.0134 - val_acc: 0.9960
# Epoch 49/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 3.7839e-05 - acc: 1.0000 - val_loss: 0.0165 - val_acc: 0.9960
# Epoch 50/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 3.1989e-05 - acc: 1.0000 - val_loss: 0.0151 - val_acc: 0.9960
# Epoch 51/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 3.3160e-05 - acc: 1.0000 - val_loss: 0.0145 - val_acc: 0.9960
# Epoch 52/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 4.0171e-05 - acc: 1.0000 - val_loss: 0.0145 - val_acc: 0.9960
# Epoch 53/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 4.6349e-05 - acc: 1.0000 - val_loss: 0.0144 - val_acc: 0.9960
# Epoch 54/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 2.9895e-05 - acc: 1.0000 - val_loss: 0.0137 - val_acc: 0.9960
# Epoch 55/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 2.6048e-05 - acc: 1.0000 - val_loss: 0.0136 - val_acc: 0.9960
# Epoch 56/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 2.9758e-05 - acc: 1.0000 - val_loss: 0.0135 - val_acc: 0.9960
# Epoch 57/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 2.5931e-05 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 0.9960
# Epoch 58/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 2.5220e-05 - acc: 1.0000 - val_loss: 0.0136 - val_acc: 0.9960
# Epoch 59/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 2.6605e-05 - acc: 1.0000 - val_loss: 0.0135 - val_acc: 0.9960
# Epoch 60/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 2.1223e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 61/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 2.0320e-05 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 0.9960
# Epoch 62/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.9438e-05 - acc: 1.0000 - val_loss: 0.0135 - val_acc: 0.9960
# Epoch 63/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 2.0674e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 64/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.7734e-05 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 0.9960
# Epoch 65/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 2.1782e-05 - acc: 1.0000 - val_loss: 0.0137 - val_acc: 0.9960
# Epoch 66/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.9287e-05 - acc: 1.0000 - val_loss: 0.0134 - val_acc: 0.9960
# Epoch 67/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.7471e-05 - acc: 1.0000 - val_loss: 0.0134 - val_acc: 0.9960
# Epoch 68/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.8216e-05 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 0.9960
# Epoch 69/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.5396e-05 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 0.9960
# Epoch 70/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 1.5681e-05 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 71/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.4248e-05 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9960
# Epoch 72/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.4842e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 73/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.4363e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 74/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.3331e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 75/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.3234e-05 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 76/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.4268e-05 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 77/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.4580e-05 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 78/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.1885e-05 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9960
# Epoch 79/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.3725e-05 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9960
# Epoch 80/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.2733e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 81/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.1804e-05 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 82/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.1441e-05 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 83/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.1760e-05 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 84/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 1.1881e-05 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 85/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.1169e-05 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9960
# Epoch 86/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.0096e-05 - acc: 1.0000 - val_loss: 0.0123 - val_acc: 0.9960
# Epoch 87/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 1.0380e-05 - acc: 1.0000 - val_loss: 0.0127 - val_acc: 0.9960
# Epoch 88/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 9.8747e-06 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9960
# Epoch 89/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 8.4738e-06 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 90/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 8.3090e-06 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 91/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 9.0149e-06 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 92/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 9.5391e-06 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9960
# Epoch 93/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 9.4120e-06 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 94/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 7.1507e-06 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9960
# Epoch 95/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 7.4816e-06 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 96/100
# 2268/2268 [==============================] - 45s 20ms/step - loss: 6.8752e-06 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9960
# Epoch 97/100
# 2268/2268 [==============================] - 44s 19ms/step - loss: 7.3728e-06 - acc: 1.0000 - val_loss: 0.0127 - val_acc: 0.9960
# Epoch 98/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 5.6966e-06 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9960
# Epoch 99/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 8.1962e-06 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 100/100
# 2268/2268 [==============================] - 44s 20ms/step - loss: 6.2585e-06 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9960

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
lb.classes_
# Out:
# array(['circle', 'down', 'eight', 'left', 'nine', 'right', 'seven', 'six',
#        'up', 'v', 'w', 'x', 'y', 'z', 'zero'], dtype='<U6')

# %%
preds = cnn.predict(x_test_img)
class_index = preds.argmax(axis=-1)
preds_labels = []
print(x_test)
for index in class_index:
    preds_labels.append(lb.classes_[index])
print(preds_labels)
# Out:
# 915     /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/eight/IMG...
# 350     /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/down/IMG_...
# 702     /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/right/rig...
# 2247    /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/y/IMG_332...
# 2321    /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/y/IMG_335...
#                               ...
# 752     /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/right/rig...
# 1445    /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/six/IMG_4...
# 720     /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/right/rig...
# 1893    /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/w/IMG_513...
# 2161    /Users/ongcj/Dev/mdp/ir/cnn/cnn_data/x/IMG_289...
# Name: img_path, Length: 252, dtype: object
# ['eight', 'down', 'right', 'y', 'y', 'seven', 'x', 'z', 'nine', 'up', 'down', 'left', 'zero', 'up', 'y', 'six', 'eight', 'up', 'nine', 'z', 'zero', 'six', 'x', 'w', 'w', 'right', 'y', 'eight', 'left', 'seven', 'down', 'w', 'x', 'z', 'w', 'eight', 'v', 'down', 'down', 'right', 'left', 'y', 'nine', 'w', 'left', 'y', 'eight', 'circle', 'circle', 'right', 'v', 'seven', 'up', 'z', 'eight', 'circle', 'seven', 'z', 'z', 'nine', 'x', 'w', 'up', 'up', 'x', 'x', 'nine', 'circle', 'down', 'zero', 'left', 'circle', 'six', 'nine', 'six', 'x', 'nine', 'six', 'x', 'right', 'nine', 'eight', 'left', 'w', 'down', 'v', 'nine', 'seven', 'nine', 'zero', 'down', 'x', 'circle', 'v', 'six', 'nine', 'x', 'v', 'zero', 'z', 'seven', 'z', 'v', 'v', 'w', 'seven', 'six', 'v', 'nine', 'left', 'circle', 'w', 'right', 'down', 'x', 'v', 'down', 'z', 'v', 'six', 'left', 'up', 'up', 'down', 'up', 'z', 'six', 'circle', 'zero', 'x', 'zero', 'up', 'v', 'z', 'seven', 'zero', 'z', 'z', 'eight', 'v', 'eight', 'six', 'left', 'seven', 'up', 'x', 'down', 'x', 'v', 'left', 'seven', 'six', 'right', 'circle', 'circle', 'eight', 'circle', 'w', 'up', 'x', 'circle', 'left', 'y', 'circle', 'down', 'seven', 'right', 'y', 'seven', 'right', 'z', 'zero', 'y', 'right', 'left', 'v', 'z', 'right', 'w', 'w', 'down', 'eight', 'w', 'right', 'six', 'zero', 'seven', 'circle', 'eight', 'right', 'left', 'zero', 'six', 'y', 'zero', 'y', 'x', 'seven', 'zero', 'circle', 'y', 'six', 'nine', 'circle', 'left', 'eight', 'z', 'left', 'up', 'y', 'nine', 'eight', 'w', 'zero', 'circle', 'eight', 'left', 'w', 'v', 'y', 'y', 'zero', 'y', 'right', 'w', 'v', 'six', 'six', 'zero', 'seven', 'up', 'z', 'x', 'left', 'nine', 'nine', 'eight', 'seven', 'nine', 'down', 'seven', 'down', 'up', 'right', 'zero', 'y', 'up', 'right', 'six', 'right', 'w', 'x']

# %%
accuracy_score(lb.inverse_transform(y_test), preds_labels)
# Out:
# 0.996031746031746

# %%
cnn.save_weights('final.h5')
